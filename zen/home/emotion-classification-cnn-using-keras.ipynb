# %% [markdown]
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
# Importing Deep Learning Libraries
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
from tensorflow.keras.models import Model,Sequential, load_model
from tensorflow.keras.optimizers import Adam,SGD,RMSprop

# %% [markdown]
# # Displaying Images

# %%
picture_size = 48
folder_path = "C:\\Users\\dc\\Desktop\\Emotion_Detection_CNN\\face-expression-recognition-dataset\\images\\"

# %%
expression = 'happy'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train\\"+expression+"\\"+ os.listdir(folder_path + "train\\" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %%
expression = 'neutral'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train\\"+expression+"\\"+ os.listdir(folder_path + "train\\" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %%
expression = 'surprise'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train\\"+expression+"\\"+ os.listdir(folder_path + "train\\" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %%
expression = 'sad'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train\\"+expression+"\\"+ os.listdir(folder_path + "train\\" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %%
expression = 'fear'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train\\"+expression+"\\"+ os.listdir(folder_path + "train\\" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %%
expression = 'angry'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train\\"+expression+"\\"+ os.listdir(folder_path + "train\\" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %%
expression = 'disgust'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train\\"+expression+"\\"+ os.listdir(folder_path + "train\\" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %%
expression = 'Closed_Eyes'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train\\"+expression+"\\"+ os.listdir(folder_path + "train\\" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %% [markdown]
# # Making Training and Validation Data

# %%
batch_size  = 128

datagen_train  = ImageDataGenerator()
datagen_val = ImageDataGenerator()

train_set = datagen_train.flow_from_directory(folder_path+"train",
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale",
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=True)


test_set = datagen_val.flow_from_directory(folder_path+"validation",
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale",
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=False)
# Out:
# Found 30581 images belonging to 8 classes.
# Found 7306 images belonging to 8 classes.

# %% [markdown]
# # Model Building

# %%
from tensorflow.keras.optimizers import Adam,SGD,RMSprop


no_of_classes = 8

model = Sequential()

#1st CNN layer
model.add(Conv2D(64,(3,3),padding = 'same',input_shape = (48,48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

#2nd CNN layer
model.add(Conv2D(128,(5,5),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#3rd CNN layer
model.add(Conv2D(512,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#4th CNN layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

#Fully connected 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))


# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(no_of_classes, activation='softmax'))



opt = Adam(lr = 0.0001)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 512)       2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 4104
# =================================================================
# Total params: 4,479,240
# Trainable params: 4,475,272
# Non-trainable params: 3,968
# _________________________________________________________________

# %% [markdown]
# # Fitting the Model with Training and Validation Data

# %%
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint("./model.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# early_stopping = EarlyStopping(monitor='val_loss',
#                           min_delta=0,
#                           patience=3,
#                           verbose=1,
#                           restore_best_weights=True
#                           )

reduce_learningrate = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)

# callbacks_list = [early_stopping,checkpoint,reduce_learningrate]

epochs = 48

model.compile(loss='categorical_crossentropy',
              optimizer = Adam(lr=0.001),
              metrics=['accuracy'])

# %%
history = model.fit(x=train_set,
                                steps_per_epoch=train_set.n//train_set.batch_size,
                                epochs=epochs,
                                validation_data = test_set,
                                validation_steps = test_set.n//test_set.batch_size
#                                 callbacks=callbacks_list
                                )
# Out:
# Epoch 1/48
# 238/238 [==============================] - 11s 41ms/step - loss: 0.8536 - accuracy: 0.6771 - val_loss: 1.0861 - val_accuracy: 0.6057
# Epoch 2/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.7883 - accuracy: 0.7055 - val_loss: 1.0857 - val_accuracy: 0.6109
# Epoch 3/48
# 238/238 [==============================] - 10s 40ms/step - loss: 0.7424 - accuracy: 0.7173 - val_loss: 1.0302 - val_accuracy: 0.6362
# Epoch 4/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.7002 - accuracy: 0.7378 - val_loss: 1.2697 - val_accuracy: 0.5529
# Epoch 5/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.6490 - accuracy: 0.7603 - val_loss: 1.0380 - val_accuracy: 0.6282
# Epoch 6/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.6169 - accuracy: 0.7703 - val_loss: 1.1521 - val_accuracy: 0.6046
# Epoch 7/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.5765 - accuracy: 0.7848 - val_loss: 1.0844 - val_accuracy: 0.6272
# Epoch 8/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.5198 - accuracy: 0.8056 - val_loss: 1.0369 - val_accuracy: 0.6390
# Epoch 9/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.4940 - accuracy: 0.8151 - val_loss: 1.2052 - val_accuracy: 0.6324
# Epoch 10/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.4526 - accuracy: 0.8322 - val_loss: 1.1160 - val_accuracy: 0.6491
# Epoch 11/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.4155 - accuracy: 0.8474 - val_loss: 1.2653 - val_accuracy: 0.6242
# Epoch 12/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.3929 - accuracy: 0.8553 - val_loss: 1.2792 - val_accuracy: 0.5988
# Epoch 13/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.3683 - accuracy: 0.8645 - val_loss: 1.4139 - val_accuracy: 0.5935
# Epoch 14/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.3382 - accuracy: 0.8782 - val_loss: 1.3950 - val_accuracy: 0.6112
# Epoch 15/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.3175 - accuracy: 0.8824 - val_loss: 1.4841 - val_accuracy: 0.5887
# Epoch 16/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.2992 - accuracy: 0.8911 - val_loss: 1.6150 - val_accuracy: 0.5762
# Epoch 17/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.2763 - accuracy: 0.8994 - val_loss: 1.3666 - val_accuracy: 0.6325
# Epoch 18/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.2662 - accuracy: 0.9018 - val_loss: 1.4396 - val_accuracy: 0.6368
# Epoch 19/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.2547 - accuracy: 0.9084 - val_loss: 1.3757 - val_accuracy: 0.6460
# Epoch 20/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.2348 - accuracy: 0.9142 - val_loss: 1.5117 - val_accuracy: 0.6221
# Epoch 21/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.2179 - accuracy: 0.9230 - val_loss: 1.4575 - val_accuracy: 0.6538
# Epoch 22/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.2125 - accuracy: 0.9256 - val_loss: 1.5149 - val_accuracy: 0.6198
# Epoch 23/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.2046 - accuracy: 0.9264 - val_loss: 1.6102 - val_accuracy: 0.6406
# Epoch 24/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1970 - accuracy: 0.9293 - val_loss: 1.5810 - val_accuracy: 0.6356
# Epoch 25/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1875 - accuracy: 0.9344 - val_loss: 1.6212 - val_accuracy: 0.6075
# Epoch 26/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1805 - accuracy: 0.9361 - val_loss: 1.5716 - val_accuracy: 0.6345
# Epoch 27/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1651 - accuracy: 0.9423 - val_loss: 1.5513 - val_accuracy: 0.6538
# Epoch 28/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1602 - accuracy: 0.9445 - val_loss: 1.6308 - val_accuracy: 0.6423
# Epoch 29/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1553 - accuracy: 0.9461 - val_loss: 1.7785 - val_accuracy: 0.6164
# Epoch 30/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1493 - accuracy: 0.9481 - val_loss: 1.7111 - val_accuracy: 0.6223
# Epoch 31/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1466 - accuracy: 0.9486 - val_loss: 1.7064 - val_accuracy: 0.6404
# Epoch 32/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1455 - accuracy: 0.9468 - val_loss: 1.6949 - val_accuracy: 0.6451
# Epoch 33/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1405 - accuracy: 0.9502 - val_loss: 1.7585 - val_accuracy: 0.6197
# Epoch 34/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1402 - accuracy: 0.9507 - val_loss: 2.1897 - val_accuracy: 0.5462
# Epoch 35/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1378 - accuracy: 0.9522 - val_loss: 1.7257 - val_accuracy: 0.6376
# Epoch 36/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1313 - accuracy: 0.9539 - val_loss: 1.9346 - val_accuracy: 0.6057
# Epoch 37/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1345 - accuracy: 0.9500 - val_loss: 1.9467 - val_accuracy: 0.6103
# Epoch 38/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1196 - accuracy: 0.9582 - val_loss: 1.9949 - val_accuracy: 0.6214
# Epoch 39/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1216 - accuracy: 0.9569 - val_loss: 1.7317 - val_accuracy: 0.6375
# Epoch 40/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1233 - accuracy: 0.9559 - val_loss: 1.7776 - val_accuracy: 0.6478
# Epoch 41/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1145 - accuracy: 0.9612 - val_loss: 1.8147 - val_accuracy: 0.6519
# Epoch 42/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1148 - accuracy: 0.9582 - val_loss: 1.8632 - val_accuracy: 0.6282
# Epoch 43/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1172 - accuracy: 0.9587 - val_loss: 1.7984 - val_accuracy: 0.6441
# Epoch 44/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1082 - accuracy: 0.9612 - val_loss: 1.7829 - val_accuracy: 0.6509
# Epoch 45/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1054 - accuracy: 0.9619 - val_loss: 2.4525 - val_accuracy: 0.5803
# Epoch 46/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1047 - accuracy: 0.9632 - val_loss: 1.8072 - val_accuracy: 0.6478
# Epoch 47/48
# 238/238 [==============================] - 10s 41ms/step - loss: 0.1144 - accuracy: 0.9593 - val_loss: 1.9012 - val_accuracy: 0.6325
# Epoch 48/48
# 238/238 [==============================] - 10s 40ms/step - loss: 0.1111 - accuracy: 0.9613 - val_loss: 1.8918 - val_accuracy: 0.6283

# %% [markdown]
# # Plotting Accuracy & Loss

# %%
model.save('model.h5')

# %%
plt.style.use('dark_background')

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
